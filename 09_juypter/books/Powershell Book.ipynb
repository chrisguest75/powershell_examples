# %%
write-host("hello-world")
# Out:
# <div>
#     <div id='dotnet-interactive-this-cell-68.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
#         The below script needs to be able to find the current output cell; this is an easy method to get it.
#     </div>
#     <script type='text/javascript'>
# async function probeAddresses(probingAddresses) {
#     function timeout(ms, promise) {
#         return new Promise(function (resolve, reject) {
#             setTimeout(function () {
#                 reject(new Error('timeout'))
#             }, ms)
#             promise.then(resolve, reject)
#         })
#     }
#
#     if (Array.isArray(probingAddresses)) {
#         for (let i = 0; i < probingAddresses.length; i++) {
#
#             let rootUrl = probingAddresses[i];
#
#             if (!rootUrl.endsWith('/')) {
#                 rootUrl = `${rootUrl}/`;
#             }
#
#             try {
#                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
# ...

# %%
$psversiontable
# Out:
# <div>
#     <div id='dotnet-interactive-this-cell-68.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
#         The below script needs to be able to find the current output cell; this is an easy method to get it.
#     </div>
#     <script type='text/javascript'>
# async function probeAddresses(probingAddresses) {
#     function timeout(ms, promise) {
#         return new Promise(function (resolve, reject) {
#             setTimeout(function () {
#                 reject(new Error('timeout'))
#             }, ms)
#             promise.then(resolve, reject)
#         })
#     }
#
#     if (Array.isArray(probingAddresses)) {
#         for (let i = 0; i < probingAddresses.length; i++) {
#
#             let rootUrl = probingAddresses[i];
#
#             if (!rootUrl.endsWith('/')) {
#                 rootUrl = `${rootUrl}/`;
#             }
#
#             try {
#                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
# ...

# %%
gps | where ProcessName | sort-object -Property Id -Descending
# Out:
#  NPM(K)    PM(M)      WS(M)     CPU(s)      Id  SI ProcessName
#  ------    -----      -----     ------      --  -- -----------
#       0     0.00     207.55       3.62     170 153 dotnet-interactive
#       0     0.00      63.52       0.52     153 153 dotnet
#       0     0.00      74.16       2.52       1   1 jupyter-notebook

# %%
dir env:*
# Out:
# Name                           Value
# ----                           -----
# SHLVL                          0
# PSModulePath                   /root/.dotnet/tools/.store/microsoft.dotnet-interactive/1.0.310301/…
# PYENV_HOOK_PATH                /home/root/.pyenv/pyenv.d:/usr/local/etc/pyenv.d:/etc/pyenv.d:/usr/…
# PATH                           /home/root/.pyenv/versions/3.9.2/bin:/home/root/.pyenv/libexec:/hom…
# PYDEVD_USE_FRAME_EVAL          NO
# HOSTNAME                       6a419d25e82d
# LANGUAGE                       en_US:en
# PWD                            /workbench
# HOME                           /home/root
# LC_ALL                         en_US.UTF-8
# PYENV_ROOT                     /home/root/.pyenv
# POWERSHELL_DISTRIBUTION_CHANN… dotnet-interactive-powershell
# LANG                           en_US.UTF-8
# PYENV_VERSION                  3.9.2
# PYENV_DIR                      /workbench
# JPY_PARENT_PID                 1

# %%
get-childitem "/"
# Out:
#     Directory: /
#
# UnixMode   User             Group                 LastWriteTime           Size Name
# --------   ----             -----                 -------------           ---- ----
# lrwxrwxrwx root             root                3/16/2022 17:07              7 bin -> usr/bin
# drwxr-xr-x root             root                4/15/2020 11:09           4096 boot
# drwxr-xr-x root             root                3/20/2022 09:59            340 dev
# drwxr-xr-x root             root                3/20/2022 09:59           4096 etc
# drwxr-xr-x root             root                3/20/2022 09:56           4096 home
# lrwxrwxrwx root             root                3/16/2022 17:07              7 lib -> usr/lib
# lrwxrwxrwx root             root                3/16/2022 17:07              9 lib32 -> usr/lib32
# lrwxrwxrwx root             root                3/16/2022 17:07              9 lib64 -> usr/lib64
# ...
